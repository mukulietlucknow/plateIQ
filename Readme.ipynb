# %% [markdown]
# ## API Documentation

# %% [markdown]
# 1. ``File Upload`` - Upload The file for Further Processing
# ### ``POST``

# %% [raw]
# http://127.0.0.1:8000/v1/upload/

# %% [markdown]
# ### Info
# * Account_id : This the client UID
# * Remark : This is an optional field in case client want to give some   remark for the submission
# Note : - Attach the file in the form request body

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. ``FileViewSet``
# ### ``GET``  ``POST``  ``PATCH``  ``PUT`` ``DELETE``

# %% [markdown]
# `` Base API ``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/files/

# %% [raw]
# HTTP 200 OK
# Allow: GET, POST, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# [
#     {
#         "id": 9,
#         "invoice": "http://127.0.0.1:8000/media/ML_File_lOm3Ckz.pdf",
#         "account_id": "12345",
#         "remark": "Mcafee",
#         "timestamp": "2020-09-03T19:09:33.908237Z"
#     },
#     {
#         "id": 10,
#         "invoice": "http://127.0.0.1:8000/media/ML_File_GIcPNTJ.pdf",
#         "account_id": "12345",
#         "remark": "Mcafee",
#         "timestamp": "2020-09-03T19:50:38.851253Z"
#     },
#     {
#         "id": 11,
#         "invoice": "http://127.0.0.1:8000/media/ML_File.pdf",
#         "account_id": "12345",
#         "remark": "Mcafee",
#         "timestamp": "2020-09-04T06:55:58.008584Z"
#     },
#     {
#         "id": 12,
#         "invoice": "http://127.0.0.1:8000/media/ML_File_EPie360.pdf",
#         "account_id": "12345",
#         "remark": "Mcafee",
#         "timestamp": "2020-09-04T06:56:03.800668Z"
#     }
# ]

# %% [markdown]
# 3. `` Check Status of the file `` For Client
#
# ### `` GET ``

# %% [raw]
# http://127.0.0.1:8000/v1/status/12345

# %% [raw]
# HTTP 200 OK
# Allow: GET, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# [
#     {
#         "id": 1,
#         "file_name": "ML File.pdf",
#         "account_id": "12345",
#         "invoice_id": "9",
#         "status": "InProgress",
#         "digitalized": false,
#         "timestamp": "2020-09-03T19:09:34.100357Z"
#     },
#     {
#         "id": 2,
#         "file_name": "ML File.pdf",
#         "account_id": "12345",
#         "invoice_id": "10",
#         "status": "InProgress",
#         "digitalized": false,
#         "timestamp": "2020-09-03T19:50:39.301123Z"
#     },
#     {
#         "id": 3,
#         "file_name": "/media/ML_File.pdf",
#         "account_id": "12345",
#         "invoice_id": "11",
#         "status": "InProgress",
#         "digitalized": false,
#         "timestamp": "2020-09-04T06:55:58.214600Z"
#     },
#     {
#         "id": 4,
#         "file_name": "/media/ML_File_EPie360.pdf",
#         "account_id": "12345",
#         "invoice_id": "12",
#         "status": "InProgress",
#         "digitalized": false,
#         "timestamp": "2020-09-04T06:56:04.021209Z"
#     },
#     {
#         "id": 5,
#         "file_name": "ML_File_qBeJlKb.pdf",
#         "account_id": "12345",
#         "invoice_id": "13",
#         "status": "InProgress",
#         "digitalized": false,
#         "timestamp": "2020-09-04T06:58:00.509074Z"
#     }
# ]

# %% [markdown]
# 4. ``StatusViewSet``
# ### ``GET``  ``POST``  ``PATCH``  ``PUT`` ``DELETE``

# %% [markdown]
# ``APIS ``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/invoiceStatus/1/

# %% [raw]
# GET /v1/viewset/invoiceStatus/1/
# HTTP 200 OK
# Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# {
#     "id": 1,
#     "file_name": "ML File.pdf",
#     "account_id": "12345",
#     "invoice_id": "9",
#     "status": "InProgress",
#     "digitalized": false,
#     "timestamp": "2020-09-03T19:09:34.100357Z"
# }

# %% [markdown]
# 5. ``OnlyProductsViewSet`` - It is an single product that has been mapped to vendor,customer,invoice number
# ### ``GET``  ``POST``  ``PATCH``  ``PUT`` ``DELETE``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/onlyProducts/
# http://127.0.0.1:8000/v1/viewset/onlyProducts/1

# %% [raw]
# GET /v1/viewset/onlyProducts/1/
# HTTP 200 OK
# Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# {
#     "id": 1,
#     "product_name": "Logitech KeyBoard",
#     "quantity": 1,
#     "base_price": "2000.00",
#     "tax": "18.00",
#     "discount": 10,
#     "customer_id": 1,
#     "vendor_id": 1,
#     "invoice_number": 10
# }

# %% [markdown]
# 6. ``VendorViewSet`` ``CustomerViewSet``
# ### ``GET``  ``POST``  ``PATCH``  ``PUT`` ``DELETE``
#
# ``APIS``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/vendors/
# http://127.0.0.1:8000/v1/viewset/customers/

# %% [raw]
# # HTTP 200 OK
# Allow: GET, POST, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# [
#     {
#         "id": 1,
#         "name": "PlateQ",
#         "address": "INDIA",
#         "UIN": "AXFPV7899A",
#         "created_at": "2020-09-04T18:21:21.933698Z",
#         "updated_at": "2020-09-04T18:21:21.933698Z",
#         "invoice_number": 10
#     }
# ]

# %% [raw]
# HTTP 200 OK
# Allow: GET, POST, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# [
#     {
#         "id": 1,
#         "name": "Mukul",
#         "address": "Bangalore",
#         "zip": "560064",
#         "created_at": "2020-09-04T18:19:56.304106Z",
#         "updated_at": "2020-09-05T14:41:34.133251Z",
#         "invoice_number": 10
#     }
# ]

# %% [markdown]
# 7. ``InvoiceViewSet``
# ### ``GET``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/invoices/
# http://127.0.0.1:8000/v1/viewset/invoices/pk
#
# Note : This is an Invoice wise Data
# It will have detailed as if it is an digitalized data for a single Invoice

# %% [raw]
# HTTP 200 OK
# Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# {
#     "id": 10,
#     "invoice": "http://127.0.0.1:8000/media/ML_File_GIcPNTJ.pdf",
#     "account_id": "12345",
#     "remark": "Mcafee",
#     "timestamp": "2020-09-03T19:50:38.851253Z",
#     "products": [
#         {
#             "id": 1,
#             "product_name": "Logitech KeyBoard",
#             "quantity": 1,
#             "base_price": "2000.00",
#             "tax": "18.00",
#             "discount": 10,
#             "customer_id": 1,
#             "vendor_id": 1,
#             "invoice_number": 10
#         },
#         {
#             "id": 2,
#             "product_name": "Key Board",
#             "quantity": 1,
#             "base_price": "2000.00",
#             "tax": "18.00",
#             "discount": 0,
#             "customer_id": 1,
#             "vendor_id": 1,
#             "invoice_number": 10
#         }
#     ],
#     "vendor": [
#         {
#             "id": 1,
#             "name": "PlateQ",
#             "address": "INDIA",
#             "UIN": "AXFPV7899A",
#             "created_at": "2020-09-04T18:21:21.933698Z",
#             "updated_at": "2020-09-04T18:21:21.933698Z",
#             "invoice_number": 10
#         }
#     ],
#     "customer": [
#         {
#             "id": 1,
#             "name": "Mukul",
#             "address": "Bangalore",
#             "zip": "560064",
#             "created_at": "2020-09-04T18:19:56.304106Z",
#             "updated_at": "2020-09-05T14:41:34.133251Z",
#             "invoice_number": 10
#         }
#     ]
# }

# %% [markdown]
# 7. ``InvoiceViewSet``
# ### ``GET``

# %% [raw]
# http://127.0.0.1:8000/v1/viewset/products/
# http://127.0.0.1:8000/v1/viewset/products/pk
#
# It is Product wise infomation and mapped with vendor and customer

# %% [raw]
# HTTP 200 OK
# Allow: GET, PUT, PATCH, DELETE, HEAD, OPTIONS
# Content-Type: application/json
# Vary: Accept
#
# {
#     "id": 1,
#     "vendor_id": {
#         "id": 1,
#         "name": "PlateQ",
#         "address": "INDIA",
#         "UIN": "AXFPV7899A",
#         "created_at": "2020-09-04T18:21:21.933698Z",
#         "updated_at": "2020-09-04T18:21:21.933698Z",
#         "invoice_number": 10
#     },
#     "customer_id": {
#         "id": 1,
#         "name": "Mukul",
#         "address": "Bangalore",
#         "zip": "560064",
#         "created_at": "2020-09-04T18:19:56.304106Z",
#         "updated_at": "2020-09-05T14:41:34.133251Z",
#         "invoice_number": 10
#     },
#     "invoice_number": {
#         "id": 10,
#         "invoice": "http://127.0.0.1:8000/media/ML_File_GIcPNTJ.pdf",
#         "account_id": "12345",
#         "remark": "Mcafee",
#         "timestamp": "2020-09-03T19:50:38.851253Z"
#     },
#     "product_name": "Logitech KeyBoard",
#     "quantity": 1,
#     "base_price": "2000.00",
#     "tax": "18.00",
#     "discount": 10
# }
